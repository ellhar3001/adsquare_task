# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime

# %%
data = pd.read_csv('/content/final_data.csv')
data.drop('Unnamed: 0',axis = 1, inplace = True)

# %%
data['DateTime'] = pd.to_datetime(data['date'])
data
# Out:
#            date      stores  ... unique visitors   DateTime
# 0    01/04/2021  McDonald's  ...               1 2021-01-04
# 1    01/06/2021  McDonald's  ...               1 2021-01-06
# 2    01/08/2021  McDonald's  ...               1 2021-01-08
# 3    01/12/2021  McDonald's  ...               1 2021-01-12
# 4    01/16/2021  McDonald's  ...               1 2021-01-16
# ..          ...         ...  ...             ...        ...
# 279  01/08/2021        Aldi  ...               2 2021-01-08
# 280  01/04/2021        Aldi  ...               1 2021-01-04
# 281  01/14/2021        Aldi  ...               1 2021-01-14
# 282  01/16/2021        Aldi  ...               1 2021-01-16
# 283  01/21/2021        Aldi  ...               1 2021-01-21
#
# [284 rows x 6 columns]

# %%
data['stores'].unique()
# Out:
# array(["McDonald's", 'Burger King', 'Subway', 'Aldi'], dtype=object)

# %%
McDonalds = data[data['stores']=="McDonald's"]
Burger_King = data[data['stores']=="Burger King"]
Subway = data[data['stores']=="Subway"]
Aldi = data[data['stores']=="Aldi"]

# %%
plt.figure(figsize=(20,8))

g = sns.lineplot(data=McDonalds, x="DateTime", y="unique visitors",hue = 'store_id')
g.set_title('McDonalds Unique Visitors')
g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
plt.figure(figsize=(20,8))

g = sns.lineplot(data=Burger_King, x="DateTime", y="unique visitors",hue = 'store_id')
g.set_title('Burger King Unique Visitors')
g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
plt.figure(figsize=(20,8))

g = sns.lineplot(data=Aldi, x="DateTime", y="unique visitors",hue = 'store_id')
g.set_title('Aldi Unique Visitors')
g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
plt.figure(figsize=(20,8))

g = sns.lineplot(data=Subway, x="DateTime", y="unique visitors",hue = 'store_id')
g.set_title('Subway Unique Visitors')
g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
Subway
# Out:
#            date  stores  store_id  total signals  unique visitors   DateTime
# 153  01/20/2021  Subway  place_52              1                1 2021-01-20
# 154  01/04/2021  Subway  place_53              1                1 2021-01-04
